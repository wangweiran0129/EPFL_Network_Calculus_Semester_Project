# %%
from network_writer import draw_net

# %%
servers = {1, 2, 3, 4}
flows = {1, 2, 3}
flows_paths= {1: [1, 2, 3], 2: [1,2], 3: [2, 3, 4]}
foi= 3

# %%
G= draw_net(servers= servers, flows= flows, flows_servers= flows_paths, foi = 3)
# Out:
# ******************************
# network id is 1
# 1
# 2
# 3
# 4
# 1
# [1, 2, 3]
# 2
# [1, 2]
# 3
# [2, 3, 4]
